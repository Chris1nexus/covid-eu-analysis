# %%
import pandas as pd

# %%
pd.read_csv("/home/xrh1/Desktop/covidlombardy/ki_cv_all/per100kdataset_from_2020-02-20_to_2020-08-20.csv")
# Out:
#      NUTS  air passengers per100k  GDP per100k  farm labour force per100k  \
# 0    AT11             2048.605922  3149.278621                2095.531796
# 1    AT12             1878.242841  3663.641648                1820.354845
# 2    AT13              315.605993  5250.512377                 110.402362
# 3    AT21               37.413615  3831.430287                1341.545325
# 4    AT22               83.039486  4078.193510                1720.160944
# ..    ...                     ...          ...                        ...
# 132  SI04              172.616531  2749.070391                2297.537076
# 133  SK01              341.252584  3939.646830                 385.309263
# 134  SK02               77.887171  1584.106082                1208.471141
# 135  SK03              106.262413  1408.905695                1052.525275
# 136  SK04               34.158545  1214.027858                 731.705519
#
#      deaths per100k  hosp discharges resp diseases per100k  \
# ...
